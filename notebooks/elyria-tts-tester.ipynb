# %%
# !bash -c "$(curl -fsSL https://raw.githubusercontent.com/nymessence/elyria-tts/main/kaggle_setup.sh)" gpu

# %%
# this is used only for image slides in video renders
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("Z.ai API Key")

# %%
# !uv venv /tmp/elyria-tts/.venv
# !uv run --python /tmp/elyria-tts/voice_synthesizer.py --script /tmp/elyria-tts/example_script_emotional.txt --device "gpu" --voice /tmp/elyria-tts/voices/nya_elyria.wav --output example.wav

# %%
import os

print(os.path.getsize("example.wav"), "bytes")
display(Audio(filename="example.wav"))
